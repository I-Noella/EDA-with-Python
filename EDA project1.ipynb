# %% [markdown]
# This data analysis is on a dataset from Kaggle which is centered on data gotten from walmart stores on sales of coffee, stating the coffee types, prices, ratings, reviews, sellers and weights

# %% [markdown]
# First, i would import the libraries needed for this analysis

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from datetime import datetime
import dateutil.parser

pd.set_option('display.max_columns', 15)
pd.set_option('expand_frame_repr', True)

sns.set_palette('hls')
# %matplotlib inline

# %% [markdown]
# Then i import my dataframe which i have named 'pers-data' for now

# %%
#importing the dataframe to be analysed and setting the index to the first column

pers_data= pd.read_csv('coffee-listings-from-all-walmart-stores.csv', index_col='title')
pers_data
# Out:
#                                                                    coffee_type  \
# title
# folgers classic roast ground coffee, 40.3-ounce                  classic roast
# café bustelo, espresso style dark roast ground ...         espresso,dark roast
# folgers classic roast ground coffee, medium roa...  medium roast,classic roast
# maxwell house original roast ground coffee, 42....                         NaN
# great value classic roast medium ground coffee,...               classic roast
# ...                                                                        ...
# xhao reusable capsules easy to clean easy to us...                         NaN
# cafe yaucono espresso dark roast ground coffee ...         espresso,dark roast
# starbucks dark roast coffee with 2x caffeine, k...          arabica,dark roast
# starbucks holiday blend, medium roast k-cup cof...        arabica,medium roast
# super coffee vanilla latte iced coffee bottle, ...           iced coffee,latte
#
#                                                     rating  reviews  \
# title
# folgers classic roast ground coffee, 40.3-ounce        3.8       93
# café bustelo, espresso style dark roast ground ...     4.7      914
# folgers classic roast ground coffee, medium roa...     4.4      740
# maxwell house original roast ground coffee, 42....     4.8     1321
# great value classic roast medium ground coffee,...     4.7     1598
# ...                                                    ...      ...
# xhao reusable capsules easy to clean easy to us...     0.0        0
# cafe yaucono espresso dark roast ground coffee ...     0.0        0
# starbucks dark roast coffee with 2x caffeine, k...     4.3     5036
# starbucks holiday blend, medium roast k-cup cof...     4.5      397
# super coffee vanilla latte iced coffee bottle, ...     4.3     2791
#
#                                                                      seller_name  \
# title
# folgers classic roast ground coffee, 40.3-ounce                      walmart.com
# café bustelo, espresso style dark roast ground ...                   walmart.com
# folgers classic roast ground coffee, medium roa...                   walmart.com
# maxwell house original roast ground coffee, 42....                   walmart.com
# great value classic roast medium ground coffee,...                   walmart.com
# ...                                                                          ...
# xhao reusable capsules easy to clean easy to us...              joybuy selection
# cafe yaucono espresso dark roast ground coffee ...  coffee & filters direct, inc
# starbucks dark roast coffee with 2x caffeine, k...                   walmart.com
# starbucks holiday blend, medium roast k-cup cof...                   walmart.com
# super coffee vanilla latte iced coffee bottle, ...                   walmart.com
#
#                                                                                             thumbnail  \
# title
# folgers classic roast ground coffee, 40.3-ounce     https://i5.walmartimages.com/asr/1fbbd523-8554...
# café bustelo, espresso style dark roast ground ...  https://i5.walmartimages.com/asr/99a53df0-0471...
# folgers classic roast ground coffee, medium roa...  https://i5.walmartimages.com/asr/e6aba325-608e...
# maxwell house original roast ground coffee, 42....  https://i5.walmartimages.com/asr/a5be9586-b75d...
# great value classic roast medium ground coffee,...  https://i5.walmartimages.com/asr/de42310c-4cd6...
# ...                                                                                               ...
# xhao reusable capsules easy to clean easy to us...  https://i5.walmartimages.com/asr/5aa587bd-9757...
# cafe yaucono espresso dark roast ground coffee ...  https://i5.walmartimages.com/asr/073bdc20-ad75...
# starbucks dark roast coffee with 2x caffeine, k...  https://i5.walmartimages.com/asr/242294ac-0c7d...
# starbucks holiday blend, medium roast k-cup cof...  https://i5.walmartimages.com/asr/3a714e3e-a30e...
# super coffee vanilla latte iced coffee bottle, ...  https://i5.walmartimages.com/asr/9f4beb5c-35c7...
#
#                                                     price         weight  \
# title
# folgers classic roast ground coffee, 40.3-ounce     13.92     40.3-ounce
# café bustelo, espresso style dark roast ground ...   3.76          10 oz
# folgers classic roast ground coffee, medium roa...   9.97     25.9 ounce
# maxwell house original roast ground coffee, 42....   9.92        42.5 oz
# great value classic roast medium ground coffee,...   9.98          48 oz
# ...                                                   ...            ...
# xhao reusable capsules easy to clean easy to us...  13.89  not mentioned
# cafe yaucono espresso dark roast ground coffee ...  10.99         8.8 oz
# starbucks dark roast coffee with 2x caffeine, k...  12.98           12 c
# starbucks holiday blend, medium roast k-cup cof...  17.72           22 c
# super coffee vanilla latte iced coffee bottle, ...   2.98  not mentioned
#
#                                                     weight_formatted_to_gramms
# title
# folgers classic roast ground coffee, 40.3-ounce                         1142.5
# café bustelo, espresso style dark roast ground ...                       283.5
# folgers classic roast ground coffee, medium roa...                       734.3
# maxwell house original roast ground coffee, 42....                      1204.9
# great value classic roast medium ground coffee,...                      1360.8
# ...                                                                        ...
# xhao reusable capsules easy to clean easy to us...                       272.2
# cafe yaucono espresso dark roast ground coffee ...                       249.5
# starbucks dark roast coffee with 2x caffeine, k...                       340.2
# starbucks holiday blend, medium roast k-cup cof...                       623.7
# super coffee vanilla latte iced coffee bottle, ...                       623.7
#
# [1400 rows x 8 columns]

# %% [markdown]
# The dataframe is named "pers_data and has 1400 rows and 8 columns

# %%
#checking the whole column headings of the dataframe

pers_data.columns.to_list()
# Out:
# ['coffee_type',
#  'rating',
#  'reviews',
#  'seller_name',
#  'thumbnail',
#  'price',
#  'weight',
#  'weight_formatted_to_gramms']

# %% [markdown]
# First glance at this dataframe, i want to answer this questions and gain the following insights from it:

# %% [markdown]
# Firstly, i would like to see the weightiest coffee, then the best rated coffee, the most sold coffee and by whom (seller's name), the coffee with the highest reviews, the relationship between the weight and the price or the ratings and the price ?? Does the weight inform the price of the coffee and all other insights i can gain from the daaset. But these will guide my thoughts and visualiztion.

# %% [markdown]
# Okay,lets get to it

# %% [markdown]
# Firstly,i would start by viewing my data, checking the types of data present in the dataset, get information and description of the data frame

# %% [markdown]
# The dataset has 8 columns with the above column headings

# %%
#checking the types of data each ccolumn has, to gain more understanding of the dataset and detect missing values per column

pers_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1400 entries, folgers classic roast ground coffee, 40.3-ounce to super coffee vanilla latte iced coffee bottle, 12 fl oz
# Data columns (total 8 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   coffee_type                 1121 non-null   object
#  1   rating                      1400 non-null   float64
#  2   reviews                     1400 non-null   int64
#  3   seller_name                 1400 non-null   object
#  4   thumbnail                   1400 non-null   object
#  5   price                       1400 non-null   float64
#  6   weight                      1400 non-null   object
#  7   weight_formatted_to_gramms  1400 non-null   float64
# dtypes: float64(3), int64(1), object(4)
# memory usage: 98.4+ KB

# %% [markdown]
# The coffee_type column is of the object type i.e it is a string.
# The rating is type float(which span accross 0-5, 0 being the lowest and 5, the highest.
# The reviews column has the integer type which depicts the numbers of reviews per coffee type.
# The seller_name column has the object type i.e the names of th sellers
# The thumbnail column has the object type
# The price column is a float
# The weight column is an object, hence the weight is formatted to grams to ensure uniformity
# The weight_formatted_to grams column is a float'
# Hence, we have 3 floats column, 1 integer column and 4 object columns

# %%
#checking the description of the numerical data and the measures of central tendencies

pers_data.describe()
# Out:
#             rating       reviews        price  weight_formatted_to_gramms
# count  1400.000000   1400.000000  1400.000000                 1400.000000
# mean      3.982643    440.853571    14.041343                  621.391786
# std       1.518037    879.351997    10.257832                  369.564693
# min       0.000000      0.000000     0.000000                    0.000000
# 25%       4.300000     16.000000     7.950000                  340.200000
# 50%       4.600000    136.000000    12.735000                  567.000000
# 75%       4.800000    604.500000    16.990000                  850.500000
# max       5.000000  15148.000000    77.090000                 2835.000000

# %% [markdown]
# This describes the numerical data in the data set
# we have 1400 observations in general with the minimum,maximum,mean,standard deviation, 25th percentile, 50th and 75th percentile for each numerical data shown above

# %%
#checking the number of categorical data types that we have

categorical = pers_data.dtypes[pers_data.dtypes=='object'].index
pers_data[categorical].describe()
# Out:
#          coffee_type  seller_name  \
# count           1121         1400
# unique           120          126
# top     medium roast  walmart.com
# freq             313         1060
#
#                                                 thumbnail         weight
# count                                                1400           1400
# unique                                                979            168
# top     https://i5.walmartimages.com/asr/6c3ab95d-29a5...  not mentioned
# freq                                                   32            169

# %% [markdown]
# The coffee_type has 1121 counts which depicts that it has 279 missing values but the seller_name is complete. coffee_type has 120 unique counts while seller_name has 126, the top seller is walmart which occurs 1060 times in the data while coffee_type has medium roast to be the top coffee and it has a frequency of 313 occurrences.
# It is important to note that i ignored the thumbnail and weight column, this is because the thumbnail column has no direct influence on the data set because it is a link that only confirms the sellers address and  weight is already formatted to grams thereby the column is not useful. in a bid to simplify my data for better visualization, i will drop these columns

# %% [markdown]
# Now, i will clean my data, starting with the miissing values, the columns not needed and the zero values

# %%
#Finding the missing values
def missing_num(x):
    return sum(x.isnull())
print('Missing values per column')

#applying our fxn by column
#check sum of missing values by column and get the columns where the sum isn't Zero

print(pers_data.apply(missing_num, axis = 0).where(lambda x: x!=0).dropna())
# Out:
# Missing values per column
# coffee_type    279.0
# dtype: float64

# %% [markdown]
# The only column with missing values is the coffee_type which has 279 missing values. i will dropthem to make a more wholesome dataframe

# %%
#dropping the missing values

new_data = pers_data.dropna()
new_data
# Out:
#                                                                     coffee_type  \
# title
# folgers classic roast ground coffee, 40.3-ounce                   classic roast
# café bustelo, espresso style dark roast ground ...          espresso,dark roast
# folgers classic roast ground coffee, medium roa...   medium roast,classic roast
# great value classic roast medium ground coffee,...                classic roast
# great value classic roast medium ground coffee,...                classic roast
# ...                                                                         ...
# nescafe classico colombia medium roast instant ...  instant coffee,medium roast
# cafe yaucono espresso dark roast ground coffee ...          espresso,dark roast
# super coffee vanilla latte iced coffee bottle, ...   2.98  not mentioned
#
#                                                     weight_formatted_to_gramms
# title
# folgers classic roast ground coffee, 40.3-ounce                         1142.5
# café bustelo, espresso style dark roast ground ...                       283.5
# folgers classic roast ground coffee, medium roa...                       734.3
# great value classic roast medium ground coffee,...                      1360.8
# great value classic roast medium ground coffee,...                       864.7
# ...                                                                        ...
# nescafe classico colombia medium roast instant ...                       272.2
# cafe yaucono espresso dark roast ground coffee ...                       249.5
# starbucks dark roast coffee with 2x caffeine, k...                       340.2
# starbucks holiday blend, medium roast k-cup cof...                       623.7
# super coffee vanilla latte iced coffee bottle, ...                       623.7
#
# [1121 rows x 8 columns]

# %% [markdown]
# My new dataframe after missing values were dropped is called "new_data".
# However, i need to also dropped some more arbitrary data

# %%
#to confirm that the missing values were really dropped
new_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1121 entries, folgers classic roast ground coffee, 40.3-ounce to super coffee vanilla latte iced coffee bottle, 12 fl oz
# Data columns (total 8 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   coffee_type                 1121 non-null   object
#  1   rating                      1121 non-null   float64
#  2   reviews                     1121 non-null   int64
#  3   seller_name                 1121 non-null   object
#  4   thumbnail                   1121 non-null   object
#  5   price                       1121 non-null   float64
#  6   weight                      1121 non-null   object
#  7   weight_formatted_to_gramms  1121 non-null   float64
# dtypes: float64(3), int64(1), object(4)
# memory usage: 78.8+ KB

# %%
#selecting the colums that i need and putting them together in a dataframe

cols = ['coffee_type', 'rating', 'reviews', 'seller_name', 'price', 'weight_formatted_to_gramms' ]
data = new_data[cols]
data
# Out:
#                                                                     coffee_type  \
# title
# folgers classic roast ground coffee, 40.3-ounce                   classic roast
# café bustelo, espresso style dark roast ground ...          espresso,dark roast
# folgers classic roast ground coffee, medium roa...   medium roast,classic roast
# great value classic roast medium ground coffee,...                classic roast
# great value classic roast medium ground coffee,...                classic roast
# ...                                                                         ...
# nescafe classico colombia medium roast instant ...  instant coffee,medium roast
# cafe yaucono espresso dark roast ground coffee ...          espresso,dark roast
# starbucks dark roast coffee with 2x caffeine, k...           arabica,dark roast
# starbucks holiday blend, medium roast k-cup cof...         arabica,medium roast
# super coffee vanilla latte iced coffee bottle, ...            iced coffee,latte
#
#                                                     rating  reviews  \
# title
# folgers classic roast ground coffee, 40.3-ounce        3.8       93
# café bustelo, espresso style dark roast ground ...     4.7      914
# folgers classic roast ground coffee, medium roa...     4.4      740
# great value classic roast medium ground coffee,...     4.7     1598
# great value classic roast medium ground coffee,...     4.2      263
# ...                                                    ...      ...
# nescafe classico colombia medium roast instant ...     4.7      122
# cafe yaucono espresso dark roast ground coffee ...     0.0        0
# starbucks dark roast coffee with 2x caffeine, k...     4.3     5036
# starbucks holiday blend, medium roast k-cup cof...     4.5      397
# super coffee vanilla latte iced coffee bottle, ...     4.3     2791
#
#                                                                      seller_name  \
# title
# folgers classic roast ground coffee, 40.3-ounce                      walmart.com
# café bustelo, espresso style dark roast ground ...                   walmart.com
# folgers classic roast ground coffee, medium roa...                   walmart.com
# great value classic roast medium ground coffee,...                   walmart.com
# great value classic roast medium ground coffee,...                   walmart.com
# ...                                                                          ...
# nescafe classico colombia medium roast instant ...                   walmart.com
# cafe yaucono espresso dark roast ground coffee ...  coffee & filters direct, inc
# starbucks dark roast coffee with 2x caffeine, k...                   walmart.com
# starbucks holiday blend, medium roast k-cup cof...                   walmart.com
# super coffee vanilla latte iced coffee bottle, ...                   walmart.com
#
#                                                     price  \
# title
# folgers classic roast ground coffee, 40.3-ounce     13.92
# café bustelo, espresso style dark roast ground ...   3.76
# folgers classic roast ground coffee, medium roa...   9.97
# great value classic roast medium ground coffee,...   9.98
# great value classic roast medium ground coffee,...   7.98
# ...                                                   ...
# nescafe classico colombia medium roast instant ...   6.28
# cafe yaucono espresso dark roast ground coffee ...  10.99
# starbucks dark roast coffee with 2x caffeine, k...  12.98
# starbucks holiday blend, medium roast k-cup cof...  17.72
# super coffee vanilla latte iced coffee bottle, ...   2.98
#
#                                                     weight_formatted_to_gramms
# title
# folgers classic roast ground coffee, 40.3-ounce                         1142.5
# café bustelo, espresso style dark roast ground ...                       283.5
# folgers classic roast ground coffee, medium roa...                       734.3
# great value classic roast medium ground coffee,...                      1360.8
# great value classic roast medium ground coffee,...                       864.7
# ...                                                                        ...
# nescafe classico colombia medium roast instant ...                       272.2
# cafe yaucono espresso dark roast ground coffee ...                       249.5
# starbucks dark roast coffee with 2x caffeine, k...                       340.2
# starbucks holiday blend, medium roast k-cup cof...                       623.7
# super coffee vanilla latte iced coffee bottle, ...                       623.7
#
# [1121 rows x 6 columns]

# %% [markdown]
# Having dropped 2 columns and 279 missing values, lets check the details of our data again

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1121 entries, folgers classic roast ground coffee, 40.3-ounce to super coffee vanilla latte iced coffee bottle, 12 fl oz
# Data columns (total 6 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   coffee_type                 1121 non-null   object
#  1   rating                      1121 non-null   float64
#  2   reviews                     1121 non-null   int64
#  3   seller_name                 1121 non-null   object
#  4   price                       1121 non-null   float64
#  5   weight_formatted_to_gramms  1121 non-null   float64
# dtypes: float64(3), int64(1), object(2)
# memory usage: 61.3+ KB

# %%
data.describe()
# Out:
#             rating       reviews        price  weight_formatted_to_gramms
# count  1121.000000   1121.000000  1121.000000                 1121.000000
# mean      4.143711    462.358608    14.016592                  623.041302
# std       1.302435    941.986003    10.668796                  361.545221
# min       0.000000      0.000000     0.000000                    8.800000
# 25%       4.300000     20.000000     7.480000                  340.200000
# 50%       4.600000    156.000000    12.580000                  623.700000
# 75%       4.700000    622.000000    16.990000                  850.500000
# max       5.000000  15148.000000    77.090000                 2835.000000

# %% [markdown]
# Duplicate data needs to be dropped so as to avoid error in the visualization

# %%
data1= data.drop_duplicates()
data1
# Out:
#                                                                     coffee_type  \
# title
# folgers classic roast ground coffee, 40.3-ounce                   classic roast
# café bustelo, espresso style dark roast ground ...          espresso,dark roast
# folgers classic roast ground coffee, medium roa...   medium roast,classic roast
# great value classic roast medium ground coffee,...                classic roast
# great value classic roast medium ground coffee,...                classic roast
# ...                                                                         ...
# nescafe classico colombia medium roast instant ...  instant coffee,medium roast
# cafe yaucono espresso dark roast ground coffee ...          espresso,dark roast
# starbucks dark roast coffee with 2x caffeine, k...           arabica,dark roast
# starbucks holiday blend, medium roast k-cup cof...         arabica,medium roast
# super coffee vanilla latte iced coffee bottle, ...            iced coffee,latte
#
#                                                     rating  reviews  \
# title
# folgers classic roast ground coffee, 40.3-ounce        3.8       93
# café bustelo, espresso style dark roast ground ...     4.7      914
# folgers classic roast ground coffee, medium roa...     4.4      740
# great value classic roast medium ground coffee,...     4.7     1598
# great value classic roast medium ground coffee,...     4.2      263
# ...                                                    ...      ...
# nescafe classico colombia medium roast instant ...     4.7      122
# cafe yaucono espresso dark roast ground coffee ...     0.0        0
# starbucks dark roast coffee with 2x caffeine, k...     4.3     5036
# starbucks holiday blend, medium roast k-cup cof...     4.5      397
# super coffee vanilla latte iced coffee bottle, ...     4.3     2791
#
#                                                                      seller_name  \
# title
# folgers classic roast ground coffee, 40.3-ounce                      walmart.com
# café bustelo, espresso style dark roast ground ...                   walmart.com
# folgers classic roast ground coffee, medium roa...                   walmart.com
# great value classic roast medium ground coffee,...                   walmart.com
# great value classic roast medium ground coffee,...                   walmart.com
# ...                                                                          ...
# nescafe classico colombia medium roast instant ...                   walmart.com
# cafe yaucono espresso dark roast ground coffee ...  coffee & filters direct, inc
# starbucks dark roast coffee with 2x caffeine, k...                   walmart.com
# starbucks holiday blend, medium roast k-cup cof...                   walmart.com
# super coffee vanilla latte iced coffee bottle, ...                   walmart.com
#
#                                                     price  \
# title
# folgers classic roast ground coffee, 40.3-ounce     13.92
# café bustelo, espresso style dark roast ground ...   3.76
# folgers classic roast ground coffee, medium roa...   9.97
# great value classic roast medium ground coffee,...   9.98
# great value classic roast medium ground coffee,...   7.98
# ...                                                   ...
# nescafe classico colombia medium roast instant ...   6.28
# cafe yaucono espresso dark roast ground coffee ...  10.99
# starbucks dark roast coffee with 2x caffeine, k...  12.98
# starbucks holiday blend, medium roast k-cup cof...  17.72
# super coffee vanilla latte iced coffee bottle, ...   2.98
#
#                                                     weight_formatted_to_gramms
# title
# folgers classic roast ground coffee, 40.3-ounce                         1142.5
# café bustelo, espresso style dark roast ground ...                       283.5
# folgers classic roast ground coffee, medium roa...                       734.3
# great value classic roast medium ground coffee,...                      1360.8
# great value classic roast medium ground coffee,...                       864.7
# ...                                                                        ...
# nescafe classico colombia medium roast instant ...                       272.2
# cafe yaucono espresso dark roast ground coffee ...                       249.5
# starbucks dark roast coffee with 2x caffeine, k...                       340.2
# starbucks holiday blend, medium roast k-cup cof...                       623.7
# super coffee vanilla latte iced coffee bottle, ...                       623.7
#
# [761 rows x 6 columns]

# %% [markdown]
# Duplicate values have been dropped, reducing our dataframe to 761 values

# %% [markdown]
# since the minumum rating should be one (on a rating basis of 1-5) it means there were some coffee that were not rated, lets see them and determine if to drop them or not

# %%
data1.loc[data1.rating==0]
# Out:
#                                                                                          coffee_type  \
# title
# 4-arabica-coffee arabica coffee plant in 4 in. pot                                           arabica
# 4-arabica-coffee arabica coffee plant in 4 in. pot                                           arabica
# french roast single coffee cup, (regular) 100% ...                       french,french roast,arabica
# caramal machiatto single coffee cup, (regular) ...                                           arabica
# kingdom coffee - african coffee, medium-light r...                                       light roast
# north pole coffee north pole blend, medium roas...                       340.2
# hawaiian isles kona chocolate macadamia medium ...                       283.5
# kauai coffee co. medium roast whole bean coffee                          283.5
# blue sail coffee - honduras, whole bean, medium...                       340.2
# blue sail coffee - volcano hiker, whole bean, m...                       340.2
# enderly coffee company - brazil single origin, ...                       955.4
# cult coffee - breakfast blend, whole bean, ligh...                       283.5
# lion diamond head espresso coffee 10 oz ground                           283.5
# enderly coffee company - brazil single origin, ...                       680.4
# blue sail coffee - salvador surf, whole bean, m...                       340.2
# cameron's specialty coffee intense french groun...                       283.5
# mad priest coffee roasters - matriarch espresso...                       283.5
# enderly coffee company - guatemala single origi...                       340.2
# pure intentions - porchlight, ground coffee, me...                      1020.6
# peach coffee roasters - ga 400 blend, whole bea...                       734.3
# spyhouse coffee - organic bold &amp; beautiful,...                       283.5
# mad priest coffee - dark night of the soul, dar...                       283.5
# cafe yaucono espresso dark roast ground coffee ...                       249.5

# %%
len(data1.loc[data1.rating==0])
# Out:
# 58

# %% [markdown]
# There are about 58 observations with zero ratings and reviews,this is going to hinder the visualization of this data, so they would be dropped going forward

# %%
#dropped the data with zero rating

suc_data = data1.drop(data1[data1.rating==0].index)
suc_data
# Out:
#                                                                     coffee_type  \
# title
# folgers classic roast ground coffee, 40.3-ounce                   classic roast
# café bustelo, espresso style dark roast ground ...          espresso,dark roast
# folgers classic roast ground coffee, medium roa...   medium roast,classic roast
# great value classic roast medium ground coffee,...                classic roast
# great value classic roast medium ground coffee,...                classic roast
# ...                                                                         ...
# the original donut shop pumpkin caramel cheesec...                caramel,latte
# nescafe classico colombia medium roast instant ...  instant coffee,medium roast
# starbucks dark roast coffee with 2x caffeine, k...           arabica,dark roast
# starbucks holiday blend, medium roast k-cup cof...         arabica,medium roast
# super coffee vanilla latte iced coffee bottle, ...            iced coffee,latte
#
#                                                     rating  reviews  \
# title
# folgers classic roast ground coffee, 40.3-ounce        3.8       93
# café bustelo, espresso style dark roast ground ...     4.7      914
# folgers classic roast ground coffee, medium roa...     4.4      740
# great value classic roast medium ground coffee,...     4.7     1598
# great value classic roast medium ground coffee,...     4.2      263
# ...                                                    ...      ...
# the original donut shop pumpkin caramel cheesec...     4.1       55
# nescafe classico colombia medium roast instant ...     4.7      122
# starbucks dark roast coffee with 2x caffeine, k...     4.3     5036
# starbucks holiday blend, medium roast k-cup cof...     4.5      397
# super coffee vanilla latte iced coffee bottle, ...     4.3     2791
#
#                                                     seller_name  price  \
# title
# folgers classic roast ground coffee, 40.3-ounce     walmart.com  13.92
# café bustelo, espresso style dark roast ground ...  walmart.com   3.76
# folgers classic roast ground coffee, medium roa...  walmart.com   9.97
# great value classic roast medium ground coffee,...  walmart.com   9.98
# great value classic roast medium ground coffee,...  walmart.com   7.98
# ...                                                         ...    ...
# the original donut shop pumpkin caramel cheesec...  walmart.com   7.92
# nescafe classico colombia medium roast instant ...  walmart.com   6.28
# starbucks dark roast coffee with 2x caffeine, k...  walmart.com  12.98
# starbucks holiday blend, medium roast k-cup cof...  walmart.com  17.72
# super coffee vanilla latte iced coffee bottle, ...  walmart.com   2.98
#
#                                                     weight_formatted_to_gramms
# title
# folgers classic roast ground coffee, 40.3-ounce                         1142.5
# café bustelo, espresso style dark roast ground ...                       283.5
# folgers classic roast ground coffee, medium roa...                       734.3
# great value classic roast medium ground coffee,...                      1360.8
# great value classic roast medium ground coffee,...                       864.7
# ...                                                                        ...
# the original donut shop pumpkin caramel cheesec...                       510.3
# nescafe classico colombia medium roast instant ...                       272.2
# starbucks dark roast coffee with 2x caffeine, k...                       340.2
# starbucks holiday blend, medium roast k-cup cof...                       623.7
# super coffee vanilla latte iced coffee bottle, ...                       623.7
#
# [703 rows x 6 columns]

# %% [markdown]
# we have reduced the data into a more compact one for a better visualization. Although for visualization that doesn't require reviews and rating the initial data 'data1' might be used.

# %% [markdown]
# Now that we dropped the coffee with zero ratings and reviews,lets check the dataframe again

# %%
suc_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 703 entries, folgers classic roast ground coffee, 40.3-ounce to super coffee vanilla latte iced coffee bottle, 12 fl oz
# Data columns (total 6 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   coffee_type                 703 non-null    object
#  1   rating                      703 non-null    float64
#  2   reviews                     703 non-null    int64
#  3   seller_name                 703 non-null    object
#  4   price                       703 non-null    float64
#  5   weight_formatted_to_gramms  703 non-null    float64
# dtypes: float64(3), int64(1), object(2)
# memory usage: 38.4+ KB

# %%
suc_data.describe()
# Out:
#            rating       reviews       price  weight_formatted_to_gramms
# count  703.000000    703.000000  703.000000                  703.000000
# mean     4.537127    549.924609   13.837553                  589.038549
# std      0.357263   1140.337577   11.146943                  394.152887
# min      1.800000      1.000000    0.000000                    8.800000
# 25%      4.500000     50.000000    6.380000                  340.200000
# 50%      4.600000    208.000000   11.490000                  453.600000
# 75%      4.700000    601.500000   17.920000                  680.400000
# max      5.000000  15148.000000   77.090000                 2835.000000

# %% [markdown]
# There are some observations on some coffee price as zero, i will view them and think of them as complementary coffee given free of charge to loyal customers and continue with them in the visualization

# %%
data.loc[data.price==0]
# Out:
#                                                                                           coffee_type  \
# title
# dunkin’ original blend coffee, medium roast cof...                                       medium roast
# dunkin’ original blend coffee, medium roast cof...                                       medium roast
# great value donut shop 100% arabica medium roas...                               arabica,medium roast
# folgers classic roast instant coffee crystals, ...                       instant coffee,classic roast
# caribou coffee, mahogany, dark roast ground cof...                                         dark roast
# tim hortons ground coffee, 100% arabica medium ...                               arabica,medium roast
# starbucks breakfast blend, medium roast k-cup c...                               arabica,medium roast
# dunkin’ original blend coffee, medium roast cof...                                       medium roast
# great value 100% arabica colombian medium dark ...  colombian,arabica,medium dark,medium dark roas...
# great value 100% arabica breakfast blend medium...                               arabica,medium roast
# great value 100% arabica french dark roast grou...                          french,arabica,dark roast
# starbucks pike place roast, medium roast k-cup ...                               arabica,medium roast
# the original donut shop regular keurig single-s...                                       medium roast
# starbucks veranda blend, starbucks blonde roast...                               blonde roast,arabica
# dunkin’ original blend coffee, medium roast cof...                                       medium roast
# dunkin’ original blend coffee, medium roast cof...                                       medium roast
# green mountain coffee hazelnut decaf coffee, ke...                                        light roast
# dunkin’ original blend coffee, medium roast cof...                                       medium roast
# green mountain coffee roasters brew over ice va...                                caramel,iced coffee
# dunkin’ original blend coffee, medium roast cof...                                       medium roast
# green mountain coffee roasters maple pecan coff...                                        light roast
# peet's coffee house blend, dark roast whole bea...                                         dark roast
# dunkin’ original blend coffee, medium roast cof...                                       medium roast
# peet's coffee luminosa breakfast blend, light r...                                        light roast
# peet's coffee single origin colombia, dark roas...                                         dark roast
# dunkin’ original blend coffee, medium roast cof...                                       medium roast
# dunkin’ original blend coffee, medium roast cof...                                       medium roast
# green mountain coffee roasters brew over ice cl...                           iced coffee,medium roast
# dunkin’ original blend coffee, medium roast cof...                                       medium roast
# dunkin’ original blend coffee, medium roast cof...                                       medium roast
# dunkin’ original blend coffee, medium roast cof...                walmart.com
# dunkin’ original blend coffee, medium roast cof...                walmart.com
# green mountain coffee hazelnut decaf coffee, ke...                walmart.com
# dunkin’ original blend coffee, medium roast cof...                walmart.com
# green mountain coffee roasters brew over ice va...                walmart.com
# dunkin’ original blend coffee, medium roast cof...                walmart.com
# green mountain coffee roasters maple pecan coff...                walmart.com
# peet's coffee house blend, dark roast whole bea...                walmart.com
# dunkin’ original blend coffee, medium roast cof...                walmart.com
# peet's coffee luminosa breakfast blend, light r...                walmart.com
# peet's coffee single origin colombia, dark roas...                walmart.com
# dunkin’ original blend coffee, medium roast cof...                walmart.com
# dunkin’ original blend coffee, medium roast cof...                walmart.com
# green mountain coffee roasters brew over ice cl...       pnwb office products
# dunkin’ original blend coffee, medium roast cof...                walmart.com
# dunkin’ original blend coffee, medium roast cof...                walmart.com
# door county coffee bourbon vanilla cream, bourb...         door county coffee
# dunkin’ original blend coffee, medium roast cof...                walmart.com
# eight o'clock, the original medium roast, groun...          shaan super store
# dunkin’ original blend coffee, medium roast cof...                walmart.com
# starbucks morning joe, ground coffee, dark roas...                walmart.com
# dunkin’ original blend coffee, medium roast cof...                walmart.com
# dunkin’ original blend coffee, medium roast cof...                walmart.com
# lavazza espresso deciso nespresso originalline ...                walmart.com
# lavazza avvolgente nespresso coffee capsules, 1...                walmart.com
# lavazza decaffeinato ricco espresso nespresso c...        myofficeinnovations
# dunkin’ original blend coffee, medium roast cof...                walmart.com
# peet's coffee k-cup pods, dark roasted, house b...                walmart.com
# hills bros. cappuccino white chocolate caramel ...        overstock drugstore
# dunkin’ original blend coffee, medium roast cof...                walmart.com
# peet's coffee k-cup pods, french roast dark roa...                walmart.com
# 1850 lantern glow coffee, light roast ground co...  bestsource officesupplies
# dunkin’ original blend coffee, medium roast cof...                walmart.com
#
#                                                     price  \
# title
# dunkin’ original blend coffee, medium roast cof...    0.0
# dunkin’ original blend coffee, medium roast cof...    0.0
# great value donut shop 100% arabica medium roas...    0.0
# folgers classic roast instant coffee crystals, ...    0.0
# caribou coffee, mahogany, dark roast ground cof...    0.0
# tim hortons ground coffee, 100% arabica medium ...    0.0
# starbucks breakfast blend, medium roast k-cup c...    0.0
# dunkin’ original blend coffee, medium roast cof...    0.0
# great value 100% arabica colombian medium dark ...    0.0
# great value 100% arabica breakfast blend medium...    0.0
# great value 100% arabica french dark roast grou...    0.0
# starbucks pike place roast, medium roast k-cup ...    0.0
# the original donut shop regular keurig single-s...    0.0
# starbucks veranda blend, starbucks blonde roast...    0.0
# dunkin’ original blend coffee, medium roast cof...    0.0
# dunkin’ original blend coffee, medium roast cof...    0.0
# green mountain coffee hazelnut decaf coffee, ke...    0.0
# dunkin’ original blend coffee, medium roast cof...    0.0
# green mountain coffee roasters brew over ice va...    0.0
# dunkin’ original blend coffee, medium roast cof...    0.0
# green mountain coffee roasters maple pecan coff...    0.0
# peet's coffee house blend, dark roast whole bea...    0.0
# dunkin’ original blend coffee, medium roast cof...    0.0
# peet's coffee luminosa breakfast blend, light r...    0.0
# peet's coffee single origin colombia, dark roas...    0.0
# dunkin’ original blend coffee, medium roast cof...    0.0
# dunkin’ original blend coffee, medium roast cof...    0.0
# green mountain coffee roasters brew over ice cl...    0.0
# dunkin’ original blend coffee, medium roast cof...    0.0
# dunkin’ original blend coffee, medium roast cof...    0.0
# door county coffee bourbon vanilla cream, bourb...    0.0
# dunkin’ original blend coffee, medium roast cof...    0.0
# eight o'clock, the original medium roast, groun...    0.0
# dunkin’ original blend coffee, medium roast cof...    0.0
# starbucks morning joe, ground coffee, dark roas...    0.0
# dunkin’ original blend coffee, medium roast cof...    0.0
# dunkin’ original blend coffee, medium roast cof...    0.0
# lavazza espresso deciso nespresso originalline ...    0.0
# lavazza avvolgente nespresso coffee capsules, 1...    0.0
# lavazza decaffeinato ricco espresso nespresso c...    0.0
# dunkin’ original blend coffee, medium roast cof...    0.0
# peet's coffee k-cup pods, dark roasted, house b...    0.0
# hills bros. cappuccino white chocolate caramel ...    0.0
# dunkin’ original blend coffee, medium roast cof...    0.0
# peet's coffee k-cup pods, french roast dark roa...    0.0
# 1850 lantern glow coffee, light roast ground co...    0.0
# dunkin’ original blend coffee, medium roast cof...    0.0
#
#                                                     weight_formatted_to_gramms
# title
# dunkin’ original blend coffee, medium roast cof...                       340.2
# dunkin’ original blend coffee, medium roast cof...                       340.2
# great value donut shop 100% arabica medium roas...                       340.2
# folgers classic roast instant coffee crystals, ...                       226.8
# caribou coffee, mahogany, dark roast ground cof...                       567.0
# tim hortons ground coffee, 100% arabica medium ...                       929.9
# starbucks breakfast blend, medium roast k-cup c...                       623.7
# dunkin’ original blend coffee, medium roast cof...                       340.2
# great value 100% arabica colombian medium dark ...                       340.2
# great value 100% arabica breakfast blend medium...                       340.2
# great value 100% arabica french dark roast grou...                       340.2
# starbucks pike place roast, medium roast k-cup ...                       623.7
# the original donut shop regular keurig single-s...                       680.4
# starbucks veranda blend, starbucks blonde roast...                       623.7
# dunkin’ original blend coffee, medium roast cof...                       340.2
# dunkin’ original blend coffee, medium roast cof...                       340.2
# green mountain coffee hazelnut decaf coffee, ke...                       680.4
# dunkin’ original blend coffee, medium roast cof...                       340.2
# green mountain coffee roasters brew over ice va...                       680.4
# dunkin’ original blend coffee, medium roast cof...                       340.2
# green mountain coffee roasters maple pecan coff...                       680.4
# peet's coffee house blend, dark roast whole bea...                       340.2
# dunkin’ original blend coffee, medium roast cof...                       340.2
# peet's coffee luminosa breakfast blend, light r...                       297.7
# peet's coffee single origin colombia, dark roas...                       297.7
# dunkin’ original blend coffee, medium roast cof...                       340.2
# dunkin’ original blend coffee, medium roast cof...                       340.2
# green mountain coffee roasters brew over ice cl...                       680.4
# dunkin’ original blend coffee, medium roast cof...                       340.2
# dunkin’ original blend coffee, medium roast cof...                       340.2
# door county coffee bourbon vanilla cream, bourb...                       283.5
# dunkin’ original blend coffee, medium roast cof...                       340.2
# eight o'clock, the original medium roast, groun...                       340.2
# dunkin’ original blend coffee, medium roast cof...                       340.2
# starbucks morning joe, ground coffee, dark roas...                       340.2
# dunkin’ original blend coffee, medium roast cof...                       340.2
# dunkin’ original blend coffee, medium roast cof...                       340.2
# lavazza espresso deciso nespresso originalline ...                       283.5
# lavazza avvolgente nespresso coffee capsules, 1...                       283.5
# lavazza decaffeinato ricco espresso nespresso c...                       283.5
# dunkin’ original blend coffee, medium roast cof...                       340.2
# peet's coffee k-cup pods, dark roasted, house b...                       623.7
# hills bros. cappuccino white chocolate caramel ...                       453.6
# dunkin’ original blend coffee, medium roast cof...                       340.2
# peet's coffee k-cup pods, french roast dark roa...                       680.4
# 1850 lantern glow coffee, light roast ground co...                       340.2
# dunkin’ original blend coffee, medium roast cof...                       340.2

# %% [markdown]
# Renaming my data for easier reference because it looks like i have a cleaner data ready for exploration

# %%
final_data= suc_data
final_data
# Out:
#                                                                     coffee_type  \
# title
# folgers classic roast ground coffee, 40.3-ounce                   classic roast
# café bustelo, espresso style dark roast ground ...          espresso,dark roast
# folgers classic roast ground coffee, medium roa...   medium roast,classic roast
# great value classic roast medium ground coffee,...                classic roast
# great value classic roast medium ground coffee,...                classic roast
# ...                                                                         ...
# the original donut shop pumpkin caramel cheesec...                caramel,latte
# nescafe classico colombia medium roast instant ...  instant coffee,medium roast
# starbucks dark roast coffee with 2x caffeine, k...           arabica,dark roast
# starbucks holiday blend, medium roast k-cup cof...         arabica,medium roast
# super coffee vanilla latte iced coffee bottle, ...            iced coffee,latte
#
#                                                     rating  reviews  \
# title
# folgers classic roast ground coffee, 40.3-ounce        3.8       93
# café bustelo, espresso style dark roast ground ...     4.7      914
# folgers classic roast ground coffee, medium roa...     4.4      740
# great value classic roast medium ground coffee,...     4.7     1598
# great value classic roast medium ground coffee,...     4.2      263
# ...                                                    ...      ...
# the original donut shop pumpkin caramel cheesec...     4.1       55
# nescafe classico colombia medium roast instant ...     4.7      122
# starbucks dark roast coffee with 2x caffeine, k...     4.3     5036
# starbucks holiday blend, medium roast k-cup cof...     4.5      397
# super coffee vanilla latte iced coffee bottle, ...     4.3     2791
#
#                                                     seller_name  price  \
# title
# folgers classic roast ground coffee, 40.3-ounce     walmart.com  13.92
# café bustelo, espresso style dark roast ground ...  walmart.com   3.76
# folgers classic roast ground coffee, medium roa...  walmart.com   9.97
# great value classic roast medium ground coffee,...  walmart.com   9.98
# great value classic roast medium ground coffee,...  walmart.com   7.98
# ...                                                         ...    ...
# the original donut shop pumpkin caramel cheesec...  walmart.com   7.92
# nescafe classico colombia medium roast instant ...  walmart.com   6.28
# starbucks dark roast coffee with 2x caffeine, k...  walmart.com  12.98
# starbucks holiday blend, medium roast k-cup cof...  walmart.com  17.72
# super coffee vanilla latte iced coffee bottle, ...  walmart.com   2.98
#
#                                                     weight_formatted_to_gramms
# title
# folgers classic roast ground coffee, 40.3-ounce                         1142.5
# café bustelo, espresso style dark roast ground ...                       283.5
# folgers classic roast ground coffee, medium roa...                       734.3
# great value classic roast medium ground coffee,...                      1360.8
# great value classic roast medium ground coffee,...                       864.7
# ...                                                                        ...
# the original donut shop pumpkin caramel cheesec...                       510.3
# nescafe classico colombia medium roast instant ...                       272.2
# starbucks dark roast coffee with 2x caffeine, k...                       340.2
# starbucks holiday blend, medium roast k-cup cof...                       623.7
# super coffee vanilla latte iced coffee bottle, ...                       623.7
#
# [703 rows x 6 columns]

# %% [markdown]
# lets check this data information and description again....for the last time perhaps?

# %%
final_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 703 entries, folgers classic roast ground coffee, 40.3-ounce to super coffee vanilla latte iced coffee bottle, 12 fl oz
# Data columns (total 6 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   coffee_type                 703 non-null    object
#  1   rating                      703 non-null    float64
#  2   reviews                     703 non-null    int64
#  3   seller_name                 703 non-null    object
#  4   price                       703 non-null    float64
#  5   weight_formatted_to_gramms  703 non-null    float64
# dtypes: float64(3), int64(1), object(2)
# memory usage: 38.4+ KB

# %%
final_data.describe()
# Out:
#            rating       reviews       price  weight_formatted_to_gramms
# count  703.000000    703.000000  703.000000                  703.000000
# mean     4.537127    549.924609   13.837553                  589.038549
# std      0.357263   1140.337577   11.146943                  394.152887
# min      1.800000      1.000000    0.000000                    8.800000
# 25%      4.500000     50.000000    6.380000                  340.200000
# 50%      4.600000    208.000000   11.490000                  453.600000
# 75%      4.700000    601.500000   17.920000                  680.400000
# max      5.000000  15148.000000   77.090000                 2835.000000

# %% [markdown]
# We can now start to explore our data and i will like to start with visualization using a line plot, to check for trends in the data

# %%
#lets set the figure size to be somewhat large and plot a line plot

plt.figure(figsize=(16,6))
sns.lineplot(data=final_data)
# Out:
# <AxesSubplot:xlabel='title'>

# %% [markdown]
# oops! there is not much insights to be gained from here, due to the large size of the data. Let me try to find the correlation between the weight and price. Remember what i said will guide my thoughts for this analysis above? Yeah, lets do this.

# %% [markdown]
# To find the correlation between the 'weight_formatted_to_gramms' and 'price', i'd be using a scatterplot with a regression line

# %%
#plotting a scatter plot with a regression line for the weight and price

plt.figure(figsize=(16,6))
sns.regplot(x= 'weight_formatted_to_gramms',y='price', data= final_data)
# Out:
# <AxesSubplot:xlabel='weight_formatted_to_gramms', ylabel='price'>

# %% [markdown]
# You would expect from here that the higher the weight, the higher the price (positively correlated), but this isnt so as a lot 'outliers' are seen away from the regression line which is tilting towards the fact that the variables are not really correlated. We can establish this much later in this analysis. For noe lets check another variable

# %% [markdown]
# Now, to check if the price of the coffee affects the rating given, i'd use the scatterplot again

# %%
#plotting a scatter plot with regression line for the price and rating

plt.figure(figsize=(16,6))
sns.regplot(x= 'rating',y='price', data= final_data)
# Out:
# <AxesSubplot:xlabel='rating', ylabel='price'>

# %% [markdown]
# Again, you would expect that the higher the price,the higher the rating, but this graph has again proven otherwise because the coffee having more ratings here have relatively lower prices with the  exceptions of few ones which do not. Hence, there is nothing much to see here, lets move ahead.

# %% [markdown]
# Now lets extract some insights from this data and bring out some major stuff. First, we start with the rating.

# %% [markdown]
# Lets check the best rated

# %%
#to extract the top best rated, On a scale of 5, a high rating should start from 4 and end at 5, lets see how many we have

final_data.loc[(final_data.rating > 4)]
# Out:
#                                                                             coffee_type  \
# title
# café bustelo, espresso style dark roast ground ...                  espresso,dark roast
# folgers classic roast ground coffee, medium roa...           medium roast,classic roast
# great value classic roast medium ground coffee,...                        classic roast
# great value classic roast medium ground coffee,...                        classic roast
# folgers black silk ground coffee, smooth dark r...  black silk ground coffee,dark roast
# ...                                                                                 ...
# the original donut shop pumpkin caramel cheesec...                        caramel,latte
# nescafe classico colombia medium roast instant ...          instant coffee,medium roast
# starbucks dark roast coffee with 2x caffeine, k...                   arabica,dark roast
# starbucks holiday blend, medium roast k-cup cof...                 arabica,medium roast
# super coffee vanilla latte iced coffee bottle, ...                    iced coffee,latte
#
#                                                     rating  reviews  \
# title
# café bustelo, espresso style dark roast ground ...     4.7      914
# folgers classic roast ground coffee, medium roa...     4.4      740
# great value classic roast medium ground coffee,...     4.7     1598
# great value classic roast medium ground coffee,...     4.2      263
# folgers black silk ground coffee, smooth dark r...     4.9       20
# ...                                                    ...      ...
# the original donut shop pumpkin caramel cheesec...     4.1       55
# nescafe classico colombia medium roast instant ...     4.7      122
# starbucks dark roast coffee with 2x caffeine, k...     4.3     5036
# starbucks holiday blend, medium roast k-cup cof...     4.5      397
# super coffee vanilla latte iced coffee bottle, ...     4.3     2791
#
#                                                     seller_name  price  \
# title
# café bustelo, espresso style dark roast ground ...  walmart.com   3.76
# folgers classic roast ground coffee, medium roa...  walmart.com   9.97
# great value classic roast medium ground coffee,...  walmart.com   9.98
# great value classic roast medium ground coffee,...  walmart.com   7.98
# folgers black silk ground coffee, smooth dark r...  walmart.com  13.98
# ...                                                         ...    ...
# the original donut shop pumpkin caramel cheesec...  walmart.com   7.92
# nescafe classico colombia medium roast instant ...  walmart.com   6.28
# starbucks dark roast coffee with 2x caffeine, k...  walmart.com  12.98
# starbucks holiday blend, medium roast k-cup cof...  walmart.com  17.72
# super coffee vanilla latte iced coffee bottle, ...  walmart.com   2.98
#
#                                                     weight_formatted_to_gramms
# title
# café bustelo, espresso style dark roast ground ...                       283.5
# folgers classic roast ground coffee, medium roa...                       734.3
# great value classic roast medium ground coffee,...                      1360.8
# great value classic roast medium ground coffee,...                       864.7
# folgers black silk ground coffee, smooth dark r...                       955.4
# ...                                                                        ...
# the original donut shop pumpkin caramel cheesec...                       510.3
# nescafe classico colombia medium roast instant ...                       272.2
# starbucks dark roast coffee with 2x caffeine, k...                       340.2
# starbucks holiday blend, medium roast k-cup cof...                       623.7
# super coffee vanilla latte iced coffee bottle, ...                       623.7
#
# [650 rows x 6 columns]

# %% [markdown]
# Oh! wow! we have quite a number of highly rated coffee, 650 out of 703 is a lot! Let's see who sells them. From a glance,i can see that walmart occurs a lot as a sellerin this data, i'd randomly choose to see the number of sales walmart has,just to see

# %%
#to determine the coffee with the most number of reviews, i will check for walmart stores first because it occurs often

final_data.loc[final_data.seller_name == 'walmart.com', :]
# Out:
#                                                                              coffee_type  \
# title
# great value espresso ground coffee, 10 oz                                       espresso
# chameleon organic coffee guatemala, medium roas...                          medium roast
# cafe la llave decaf espresso dark roast ground ...                   espresso,dark roast
# illy ground drip classico medium roast coffee, ...                          medium roast
# peet's coffee french roast, dark roast whole be...        french,french roast,dark roast
# ...                                                                                  ...
# nescaf clasico decaf dark roast instant coffee,...             instant coffee,dark roast
# great value classic medium roast instant coffee...           instant coffee,medium roast
# gevalia mocha latte k-cup espresso coffee pods ...  espresso,mocha,espresso coffee,latte
# 1850 black gold coffee, dark roast ground coffe...                            dark roast
# folgers classic decaf ground coffee, medium roa...                          medium roast
#
#                                                     rating  reviews  \
# title
# great value espresso ground coffee, 10 oz              3.5       54
# chameleon organic coffee guatemala, medium roas...     4.8       54
# cafe la llave decaf espresso dark roast ground ...     4.4        9
# illy ground drip classico medium roast coffee, ...     4.8      469
# peet's coffee french roast, dark roast whole be...     4.6      631
# ...                                                    ...      ...
# nescaf clasico decaf dark roast instant coffee,...     4.7      265
# great value classic medium roast instant coffee...     4.4      292
# gevalia mocha latte k-cup espresso coffee pods ...     4.5     5315
# 1850 black gold coffee, dark roast ground coffe...     4.5     4165
# folgers classic decaf ground coffee, medium roa...     4.5       64
#
#                                                     seller_name  price  \
# title
# great value espresso ground coffee, 10 oz           walmart.com   3.36
# chameleon organic coffee guatemala, medium roas...  walmart.com  14.26
# cafe la llave decaf espresso dark roast ground ...  walmart.com   2.88
# illy ground drip classico medium roast coffee, ...  walmart.com  14.52
# peet's coffee french roast, dark roast whole be...  walmart.com   9.98
# ...                                                         ...    ...
# nescaf clasico decaf dark roast instant coffee,...  walmart.com   6.32
# great value classic medium roast instant coffee...  walmart.com   3.24
# gevalia mocha latte k-cup espresso coffee pods ...  walmart.com  13.66
# 1850 black gold coffee, dark roast ground coffe...  walmart.com   8.48
# folgers classic decaf ground coffee, medium roa...  walmart.com  12.24
#
#                                                     weight_formatted_to_gramms
# title
# great value espresso ground coffee, 10 oz                                283.5
# chameleon organic coffee guatemala, medium roas...                      1204.9
# cafe la llave decaf espresso dark roast ground ...                       249.5
# illy ground drip classico medium roast coffee, ...                       249.5
# peet's coffee french roast, dark roast whole be...                       297.7
# ...                                                                        ...
# nescaf clasico decaf dark roast instant coffee,...                       640.7
# great value classic medium roast instant coffee...                       793.8
# gevalia mocha latte k-cup espresso coffee pods ...                       340.2
# 1850 black gold coffee, dark roast ground coffe...                       340.2
# folgers classic decaf ground coffee, medium roa...                       734.3
#
# [546 rows x 6 columns]

# %% [markdown]
# Walmart alone has 546 inputs!! My instinct was correct, if only walmart can sell 546 out of 703, they are the best seller, no cap! but lets see how others did in terms of sales too....More like 'top best sellers'

# %%
#to check the top best sellers,i would first group by seller_name 

group=final_data.groupby('seller_name').agg(len)
group
# Out:
#                             coffee_type  rating  reviews  price  \
# seller_name
# 101cells                              1       1        1      1
# 21wayskinnect llc                     1       1        1      1
# 54fabulous                            1       1        1      1
# a s group inc                         1       1        1      1
# alfa retailers llc                    1       1        1      1
# ...                                 ...     ...      ...    ...
# vercingetorix llc                     1       1        1      1
# vitaminics inc                        1       1        1      1
# walmart.com                         546     546      546    546
# www.hadetech.com                      1       1        1      1
# your voice your choice inc            2       2        2      2
#
#                             weight_formatted_to_gramms
# seller_name
# 101cells                                             1
# 21wayskinnect llc                                    1
# 54fabulous                                           1
# a s group inc                                        1
# alfa retailers llc                                   1
# ...                                                ...
# vercingetorix llc                                    1
# vitaminics inc                                       1
# walmart.com                                        546
# www.hadetech.com                                     1
# your voice your choice inc                           2
#
# [96 rows x 5 columns]

# %% [markdown]
# from this,we have quite a number of sellers having just one rating, review and even price,that means they sold just one. To further determine my top sellers, lets check those that have rating greater than 2

# %%
#check ratings greater than 2

group2= group.loc[(group.rating > 2)]
group2
# Out:
#                            coffee_type  rating  reviews  price  \
# seller_name
# avenue a stores llc                  6       6        6      6
# bestsource officesupplies            6       6        6      6
# blue monster llc                     3       3        3      3
# cajun supermarket                    6       6        6      6
# door county coffee                   8       8        8      8
# jadas hats                           3       3        3      3
# jesus home depot                     3       3        3      3
# matek online store llc               6       6        6      6
# metrogoods usa                       3       3        3      3
# myofficeinnovations                  7       7        7      7
# overstock drugstore                  4       4        4      4
# shaan super store                    4       4        4      4
# texas star                           3       3        3      3
# walmart.com                        546     546      546    546
#
#                            weight_formatted_to_gramms
# seller_name
# avenue a stores llc                                 6
# bestsource officesupplies                           6
# blue monster llc                                    3
# cajun supermarket                                   6
# door county coffee                                  8
# jadas hats                                          3
# jesus home depot                                    3
# matek online store llc                              6
# metrogoods usa                                      3
# myofficeinnovations                                 7
# overstock drugstore                                 4
# shaan super store                                   4
# texas star                                          3
# walmart.com                                       546

# %% [markdown]
# Okay, here they are. To aid more visualization, we would plot a barchart

# %%
#a barplot to see the top sellers and hoew many they sold

plt.figure(figsize=(16,6))
bar= sns.barplot(x=group2['rating'], y = group2.index)
bar.bar_label(bar.containers[0])
# Out:
# [Text(0, 0, '6'),
#  Text(0, 0, '6'),
#  Text(0, 0, '3'),
#  Text(0, 0, '6'),
#  Text(0, 0, '8'),
#  Text(0, 0, '3'),
#  Text(0, 0, '3'),
#  Text(0, 0, '6'),
#  Text(0, 0, '3'),
#  Text(0, 0, '7'),
#  Text(0, 0, '4'),
#  Text(0, 0, '4'),
#  Text(0, 0, '3'),
#  Text(0, 0, '546')]

# %% [markdown]
# So,here we have them, the second best seller is 'door county coffee' which has just 8 sales compared to walmart with over 540 sales. It is indeed safe to say this analysis is about walmart stores (laugh)

# %% [markdown]
# Just to use a line plot to visualize the above insights. Walmart stores hasit

# %%
#plotting a lineplotfor the best sellers

plt.figure(figsize=(16,6))
sns.lineplot(data=group2)
# Out:
# <AxesSubplot:xlabel='seller_name'>

# %% [markdown]
# Next, we will determine the best reviewed coffee. The coffee that has the highest reviews

# %%
#to determine the best reviewed coffee,we would first group by the coffee_type and reviews

review= final_data.groupby('coffee_type').reviews.agg([len, min, max])
review
# Out:
#                                                     len  min   max
# coffee_type
# americano,caffe americano,medium dark,medium da...    1    4     4
# arabica                                               5    1   613
# arabica,dark roast                                    6    2  5036
# arabica,light roast                                   1  235   235
# arabica,medium roast                                 44    8  6301
# ...                                                 ...  ...   ...
# mocha,instant coffee                                  1  235   235
# mocha,latte                                           1  505   505
# mocha,light roast                                     2   75   432
# mocha,medium roast                                    4   13  1484
# vienna                                                1  373   373
#
# [119 rows x 3 columns]

# %%
#then to grouping by the length

group3=final_data.groupby('reviews').agg(len)
group3
# Out:
#          coffee_type  rating  seller_name  price  weight_formatted_to_gramms
# reviews
# 1                 11      11           11     11                          11
# 2                  9       9            9      9                           9
# 3                  6       6            6      6                           6
# 4                  4       4            4      4                           4
# 5                 12      12           12     12                          12
# ...              ...     ...          ...    ...                         ...
# 6301               1       1            1      1                           1
# 7017               1       1            1      1                           1
# 8446               1       1            1      1                           1
# 14166              1       1            1      1                           1
# 15148              1       1            1      1                           1
#
# [439 rows x 5 columns]

# %% [markdown]
# From this table '15148' is the highest review, lets check which coffee has it in the next code

# %%
#to check the coffee_type with the highest review

final_data.loc[final_data.reviews == 15148, :]
# Out:
#                                                                    coffee_type  \
# title
# folgers classic roast ground coffee, medium roa...  medium roast,classic roast
#
#                                                     rating  reviews  \
# title
# folgers classic roast ground coffee, medium roa...     4.9    15148
#
#                                                     seller_name  price  \
# title
# folgers classic roast ground coffee, medium roa...  walmart.com  13.92
#
#                                                     weight_formatted_to_gramms
# title
# folgers classic roast ground coffee, medium roa...                      1360.8

# %% [markdown]
# This is the coffee with the highest review. coffee_type 'medium roast, classic roast' has it

# %% [markdown]
# Now lets use our description of the categorical data to further establish our best seller and get the best selling coffee too

# %%
#to check the categorical datatype

categorical2 = final_data.dtypes[final_data.dtypes=='object'].index
final_data[categorical2].describe()
# Out:
#          coffee_type  seller_name
# count            703          703
# unique           119           96
# top     medium roast  walmart.com
# freq             184          546

# %% [markdown]
# from this table, it shows that the top coffee is 'medium roast'(occurng 184 times) and is sold by 'walmart.com'
# Therefore, walmart.com is our best seller and 'Medium roast' coffee is our best selling coffee

# %% [markdown]
# Next, we will determine the best rated coffee. The coffee that has the highest rating

# %%
#to determine the best rated coffee, first groupby coffee_type and rating

final_data.groupby('coffee_type').rating.agg([len, min, max])
# Out:
#                                                     len  min  max
# coffee_type
# americano,caffe americano,medium dark,medium da...    1  4.3  4.3
# arabica                                               5  3.2  5.0
# arabica,dark roast                                    6  4.3  5.0
# arabica,light roast                                   1  4.7  4.7
# arabica,medium roast                                 44  3.1  4.9
# ...                                                 ...  ...  ...
# mocha,instant coffee                                  1  4.6  4.6
# mocha,latte                                           1  4.3  4.3
# mocha,light roast                                     2  4.1  4.3
# mocha,medium roast                                    4  3.8  4.6
# vienna                                                1  4.5  4.5
#
# [119 rows x 3 columns]

# %%
#we group again by number of occurrences of 'rating'

group4=final_data.groupby('rating').agg(len)
group4
# Out:
#         coffee_type  reviews  seller_name  price  weight_formatted_to_gramms
# rating
# 1.8               1        1            1      1                           1
# 2.1               1        1            1      1                           1
# 2.5               1        1            1      1                           1
# 2.9               1        1            1      1                           1
# 3.0               2        2            2      2                           2
# 3.1               1        1            1      1                           1
# 3.2               2        2            2      2                           2
# 3.3               2        2            2      2                           2
# 3.4               4        4            4      4                           4
# 3.5               8        8            8      8                           8
# 3.6               2        2            2      2                           2
# 3.7               4        4            4      4                           4
# 3.8               8        8            8      8                           8
# 3.9               4        4            4      4                           4
# 4.0              12       12           12     12                          12
# 4.1              12       12           12     12                          12
# 4.2              16       16           16     16                          16
# 4.3              40       40           40     40                          40
# 4.4              48       48           48     48                          48
# 4.5              91       91           91     91                          91
# 4.6             139      139          139    139                         139
# 4.7             155      155          155    155                         155
# 4.8              92       92           92     92                          92
# 4.9              30       30           30     30                          30
# 5.0              27       27           27     27                          27

# %%
#the highest rating value is '5', so lets see who has it

final_data.loc[final_data.rating == 5, :]
# Out:
#                                                                         coffee_type  \
# title
# arabica ground 100% coffee 126 pk                                           arabica
# cafe el morro espresso dark roast caffeinated g...              espresso,dark roast
# kauai coffee na pali coast k-cup coffee pods, d...                       dark roast
# black rifle coffee spirit of '76, medium roast,...  medium roast,black rifle coffee
# black rifle coffee just black single-serve pods...  medium roast,black rifle coffee
# cafe aroma espresso ground coffee, dark roast c...              espresso,dark roast
# black rifle coffee just black single-serve pods...  medium roast,black rifle coffee
# black rifle ready-to-drink coffee, espresso moc...                   espresso,mocha
# death wish coffee, organic, fair-trade, espress...          espresso,espresso roast
# black rifle coffee spirit of '76 single-serve p...  medium roast,black rifle coffee
# verena street nine mile sunset ground coffee, d...                       dark roast
# the coffee bean &amp; tea leaf house blend ligh...                      light roast
# gold coffee company 100% arabica morning blend ...               arabica,dark roast
# eldorado espresso brick 9 oz                                               espresso
# cameron's coffee jamaican me crazy ground coffe...                      light roast
# verena street cow tipper flavored ground coffee...                     medium roast
# black rifle ready-to-drink coffee, espresso wit...                         espresso
# folgers 100% colombian coffee, medium roast gro...           colombian,medium roast
# folgers half caff ground coffee, medium roast, ...                     medium roast
# ruta maya organic coffee dark roast 2.2 lbs.                             340.2
# community coffee caf special decaf medium-dark ...                      1020.6
# papanicholas italian expresso 24ct                                       680.4
# lion coffee, vanilla macadamia flavor light roa...                       680.4
# caf la carreta cuban espresso coffee 10 oz brick                         283.5
# stumptown coffee roasters organic blend whole b...                       340.2

# %% [markdown]
# These are the highest rated coffee. Oh wow! They are quite a number, you would expect to see the most epensive, weightiest and best selling coffee amongst them but no, this again confirms that there is no correlation between the rating, price, weight and the coffee_type

# %% [markdown]
# Next is to check the most expensive coffee.

# %%
#lets group the dataframe by the price column

group5=final_data.groupby('price').agg(len)
group5
# Out:
#        coffee_type  rating  reviews  seller_name  weight_formatted_to_gramms
# price
# 0.00            29      29       29           29                          29
# 1.00             2       2        2            2                           2
# 1.43             1       1        1            1                           1
# 1.78             1       1        1            1                           1
# 1.98             2       2        2            2                           2
# ...            ...     ...      ...          ...                         ...
# 60.00            1       1        1            1                           1
# 71.00            1       1        1            1                           1
# 76.99            1       1        1            1                           1
# 77.00            1       1        1            1                           1
# 77.09            1       1        1            1                           1
#
# [345 rows x 5 columns]

# %% [markdown]
# The highest price is '77.09', lets see who has it

# %%
#checking the details of the highest coffee price

final_data.loc[final_data.price ==77.09, :]
# Out:
#                                                    coffee_type  rating  \
# title
# lavazza perfetto single-serve k-cup® pods for k...  dark roast     4.2
#
#                                                     reviews  \
# title
# lavazza perfetto single-serve k-cup® pods for k...       22
#
#                                                                   seller_name  \
# title
# lavazza perfetto single-serve k-cup® pods for k...  national discount centers
#
#                                                     price  \
# title
# lavazza perfetto single-serve k-cup® pods for k...  77.09
#
#                                                     weight_formatted_to_gramms
# title
# lavazza perfetto single-serve k-cup® pods for k...                       283.5

# %% [markdown]
# This is the most expensive coffee and it can be seen even from here that the price doesn't determine the rating and the weight of the coffee because,if it did, the most expensive coffee should be the best rated(rating of 5) and also have the most weight which is not the case. This insight is consistent with the plot of price against weight above.

# %% [markdown]
# Lastly,i would create some density plots to show the distributions of the ratings, weight and price independently

# %%
#lets show the distribution of the ratings

plt.figure(figsize=(16,6))
sns.kdeplot(data=final_data['rating'], shade=True)
# Out:
# <AxesSubplot:xlabel='rating', ylabel='Density'>

# %% [markdown]
# This chart depicts that the most common coffee rating is between 4.5 to 5.0. Most of the coffee were rated to be nice

# %%
#for the weight

plt.figure(figsize=(16,6))
sns.kdeplot(data=final_data['weight_formatted_to_gramms'], shade=True)
# Out:
# <AxesSubplot:xlabel='weight_formatted_to_gramms', ylabel='Density'>

# %% [markdown]
# This chart shows that the most popular coffee weight is in between 250-500grams

# %%
#for the price

plt.figure(figsize=(16,6))
sns.kdeplot(data=final_data['price'], shade=True)
# Out:
# <AxesSubplot:xlabel='price', ylabel='Density'>

# %% [markdown]
# This chat depicts that most of the coffee prices were within the range of 10-20

# %% [markdown]
# With this i have come to the end of this analysis, i hope you werent bored and you could understand my data representation and visualization.
# Majorly, i was able to clean the data and see the relationships between the variables, i checked for the best seller, best rated coffee, coffee with the highest review, the highest selling coffee. the most expensive coffee, the top best selling stores, the weightiest coffee and i was even able to check the most popular weights of coffee and the prices.
